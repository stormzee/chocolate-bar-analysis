# %% [markdown]
# # Introduction
#
# > This is an anlysis on finding the best Chocolate bars. The dataset used in this project has to do with data on chocolate names, reviews, year reviewed, ratings, cocoa content, cocoa beans origin, manufacturer, manufacturer's location, ingredients and also number of ingredients used in making that chocolate.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('chocolate_bars.csv')

# Reading in the data
# Take a look at the first few datapoints
df
# Out:
#         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454         5150           U.S.A.           2019            Tanzania
# 1     2458         5150           U.S.A.           2019  Dominican Republic
# 2     2454         5150           U.S.A.           2019          Madagascar
# 3     2542         5150           U.S.A.           2021                Fiji
# 4     2546         5150           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2525  1205       Zotter          Austria           2014               Blend
# 2526  1996       Zotter          Austria           2017            Colombia
# 2527  2036       Zotter          Austria           2018               Blend
# 2528  2170       Zotter          Austria           2018               Congo
# 2529  2170       Zotter          Austria           2018              Belize
#
#                              bar_name  cocoa_percent  num_ingredients  \
# 0               Kokoa Kamili, batch 1           76.0              3.0
# 1                     Zorzal, batch 1           76.0              3.0
# 2              Bejofo Estate, batch 1           76.0              3.0
# 3               Matasawalevu, batch 1           68.0              3.0
# 4               Sur del Lago, batch 1           72.0              3.0
# ...                               ...            ...              ...
# 2525                              Raw           80.0              4.0
# 2526                 APROCAFA, Acandi           75.0              3.0
# 2527  Dry Aged, 30 yr Anniversary bar           75.0              3.0
# 2528            Mountains of the Moon           70.0              3.0
# 2529                         Maya Mtn           72.0              3.0
#
#      ingredients                             review  rating
# 0          B,S,C          rich cocoa, fatty, bready    3.25
# 1          B,S,C             cocoa, vegetal, savory    3.50
# 2          B,S,C       cocoa, blackberry, full body    3.75
# 3          B,S,C                chewy, off, rubbery    3.00
# 4          B,S,C  fatty, earthy, moss, nutty,chalky    3.00
# ...          ...                                ...     ...
# 2525   B,S*,C,Sa             waxy, cloying, vegetal    2.75
# 2526       B,S,C          strong nutty, marshmallow    3.75
# 2527       B,S,C               fatty, earthy, cocoa    3.00
# 2528       B,S,C       fatty, mild nuts, mild fruit    3.25
# 2529       B,S,C          muted, roasty, accessible    3.50
#
# [2530 rows x 11 columns]

# %% [markdown]
# There are 2530 data points(rows) and 11 variables(columns)

# %% [markdown]
# ## ✅ Checklist before publishing
# - Rename your workspace to make it descriptive of your work. N.B. you should leave the notebook name as notebook.ipynb.
# - **Remove redundant cells** like the introduction to data science notebooks, so the workbook is focused on your story.
# - Check that all the cells run without error.

# %% [markdown]
# ## 💪 Challenge
# Create a report to summarize your research. Include:
#
# 1. What is the average rating by country of origin?
# 2. How many bars were reviewed for each of those countries?
# 3. Create plots to visualize findings for questions 1 and 2.
# 4. Is the cacao bean's origin an indicator of quality?
# 5. [Optional] How does cocoa content relate to rating? What is the average cocoa content for bars with higher ratings (above 3.5)?
# 6. [Optional 2] Your research indicates that some consumers want to avoid bars with lecithin. Compare the average rating of bars with and without lecithin (L in the ingredients).
# 7. Summarize your findings.

# %% [markdown]
# ## 💡 Learn more
#
# The following DataCamp courses can help review the skills needed for this challenge:
#
# * [Data Manipulation with pandas](https://www.datacamp.com/courses/data-manipulation-with-pandas)
# * [Introduction to Data Visualization with Seaborn](https://www.datacamp.com/courses/introduction-to-data-visualization-with-seaborn)
# * [Introduction to Statistics in Python](https://www.datacamp.com/courses/introduction-to-statistics-in-python)

# %%
# check data types of the columns
df.dtypes
# Out:
# id                    int64
# manufacturer         object
# company_location     object
# year_reviewed         int64
# bean_origin          object
# bar_name             object
# cocoa_percent       float64
# num_ingredients     float64
# ingredients          object
# review               object
# rating              float64
# dtype: object

# %%
# check overview of columns 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   int64
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   int64
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2443 non-null   float64
#  8   ingredients       2443 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 217.5+ KB

# %% [markdown]
# From the above information, there seems to be two columns with null values and so let's investigate them further

# %%
df.isnull().sum()
# Out:
# id                   0
# manufacturer         0
# company_location     0
# year_reviewed        0
# bean_origin          0
# bar_name             0
# cocoa_percent        0
# num_ingredients     87
# ingredients         87
# review               0
# rating               0
# dtype: int64

# %% [markdown]
# There exists 87 rows with null values, let's drop them or we can choose to replace the null values in "num_ingredients" by the mean of that column. Also, dropping 87 out of 2530 will have insignificant effect on the whole dataset. Going forward, we'd know what to do.

# %%
# check for duplicates in the dataset

df.duplicated().any()
# Out:
# False

# %%
# checking to see if the empty rows 
# in "num_ingredients" and "ingredients" are on the same index

df[df['num_ingredients'].isnull() == True]
# Out:
#         id                    manufacturer company_location  year_reviewed  \
# 85    1964                   Amazing Cacao           Russia           2017
# 86    1964                   Amazing Cacao           Russia           2017
# 164    486             Artisan du Chocolat             U.K.           2010
# 293     81                          Bonnat           France           2006
# 323    341          Bouga Cacao (Tulicorp)          Ecuador           2009
# ...    ...                             ...              ...            ...
# 2424   153  Vintage Plantations (Tulicorp)           U.S.A.           2007
# 2425   153  Vintage Plantations (Tulicorp)           U.S.A.           2007
# 2426   153  Vintage Plantations (Tulicorp)           U.S.A.           2007
# 2447   733                      Whittakers      New Zealand           2011
# 2457  1109                  Willie's Cacao             U.K.           2013
#
#      bean_origin                           bar_name  cocoa_percent  \
# 85          Peru                            Maranon           70.0
# 86          Peru                        Platan Bajo           70.0
# 164    Venezuela                          Venezuela          100.0
# 293        Blend                        One Hundred          100.0
# 323      Ecuador            El Oro, Hacienda de Oro          100.0
# ...          ...                                ...            ...
# 2424     Ecuador  Los Rios, Rancho Grande 2004/2007          100.0
# 2425     Ecuador  Los Rios, Rancho Grande 2004/2007           90.0
# 2426     Ecuador  Los Rios, Rancho Grande 2004/2007           75.0
# 2447       Ghana                              Ghana           72.0
# 2457   Indonesia             Java, Indonesian Black          100.0
#
#       num_ingredients ingredients                            review  rating
# 85                NaN         NaN                  raisins, pungent    3.00
# 86                NaN         NaN  few grits, blackcherry, licorice    3.50
# 164               NaN         NaN           very nutty, very bitter    1.75
# 293               NaN         NaN               acidic, bitter, dry    1.50
# 323               NaN         NaN    cardboard, very bitter, floral    1.50
# ...               ...         ...                               ...     ...
# 2424              NaN         NaN  bland, mild fruit, strong bitter    2.00
# 2425              NaN         NaN         some fruit, strong bitter    2.00
# 2426              NaN         NaN      cocoa,earthy,very astringent    3.00
# 2447              NaN         NaN    sticky, dry, vanilla dominates    2.50
# 2457              NaN         NaN       fruit, strong smoke, bitter    2.25
#
# [87 rows x 11 columns]

# %% [markdown]
# ### My Thoughts
#
# I think that the rows which are null in the "num_ingredients" column are the same rows which are null in the "ingredients" column because, if there are no ingredients (ingredients column is null), there won't be any ingredients to be counted therefore leading to null values in the num_ingredients column.

# %%
## From here, it shows that there are null values in the dataset.
## Let's investigate the null values and deal with them.
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#                 id  year_reviewed  cocoa_percent  num_ingredients      rating
# count  2443.000000    2443.000000    2443.000000      2443.000000  2443.00000
# mean   1451.520262    2014.485878      71.496725         3.041343     3.21009
# std     755.521714       3.957507       5.156974         0.913728     0.42837
# min       5.000000    2006.000000      42.000000         1.000000     1.00000
# 25%     833.000000    2012.000000      70.000000         2.000000     3.00000
# 50%    1474.000000    2015.000000      70.000000         3.000000     3.25000
# 75%    2100.000000    2018.000000      74.000000         4.000000     3.50000
# max    2712.000000    2021.000000     100.000000         6.000000     4.00000

# %% [markdown]
# ### I checked for null values in the dataset and removed them
# After removing null values, dataset was left with 2443 rows.

# %%
# recheck for null values
df.isnull().sum()
# Out:
# id                  0
# manufacturer        0
# company_location    0
# year_reviewed       0
# bean_origin         0
# bar_name            0
# cocoa_percent       0
# num_ingredients     0
# ingredients         0
# review              0
# rating              0
# dtype: int64

# %% [markdown]
# - Now there aren't null values in the dataset and so we can continue with Exploratory Data Analysis

# %%
# Top 5 Chocolates with the highest frequncy in the dataset
df[['bar_name']].value_counts(ascending=False)
# Out:
# bar_name
# Madagascar                                       52
# Ecuador                                          38
# Peru                                             37
# Dominican Republic                               36
# Chuao                                            28
#                                                  ..
# Galapagos, Santa Cruz Island, 2018 h.             1
# Gabon                                             1
# Fruity-beta                                       1
# French Laundry 20th Anniversary, Peru, Belize     1
# the lost city, gracias a dias, batch 362          1
# Length: 1567, dtype: int64

# %%
df['bean_origin'].value_counts(ascending=False).head()
# Out:
# Venezuela             246
# Peru                  231
# Dominican Republic    220
# Ecuador               201
# Madagascar            171
# Name: bean_origin, dtype: int64

# %% [markdown]
# ### Most chocolate bars produced over the last 15 years (2006 to 2021) have their cocoa bean originating from Venezuela.
# In other words, venezuela produces greater number of cocoa bean for chocolate production worldwide.

# %%
# Number of unique chocolates in the dataset.
df.bar_name.nunique()
# Out:
# 1567

# %% [markdown]
# From the above cell, there are 1567 different chocolates in the dataset

# %%
# Top 10 countries by average of chocolate rating
country_avg_rating = df.groupby('bean_origin')[['rating']].mean().sort_values('rating', ascending=False).reset_index()

top5_bean_origin = country_avg_rating.head()
top5_bean_origin
# Out:
#            bean_origin    rating
# 0                China  3.500000
# 1  Sao Tome & Principe  3.500000
# 2      Solomon Islands  3.450000
# 3                Congo  3.318182
# 4             Thailand  3.300000

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='bean_origin', y='rating', data=top5_bean_origin, markers=True)
plt.xticks(rotation=20)
plt.show()

# %%
ax = plt.figure(figsize=(9,11))
sns.set_theme(style="whitegrid")
sns.barplot(x="rating", y="bean_origin", data=country_avg_rating)
plt.show()

# %% [markdown]
# From the above plot, china is the highly rated country where cocoa beans originate from. In other words, cocoa beans from china are mostly rated higher than cocoa beans from other countries.

# %% [markdown]
#  From the above cell, there are 62 different countries in the datasets where cocoa beans originate from.
# Chocolates made of cocoa bean from China, Sao Tome & Principe, Solomon Island, Congo and Thailand are the top five(5) highly rated chocolate bars.

# %%
manufacturer_avg_rating = df.groupby('manufacturer')[['rating']].mean().sort_values('rating', ascending=False).reset_index()

top5_bar_makers = manufacturer_avg_rating.head()
top5_bar_makers
# Out:
#                            manufacturer    rating
# 0                                Ocelot  3.875000
# 1  Heirloom Cacao Preservation (Zokoko)  3.875000
# 2                                Matale  3.812500
# 3                                Patric  3.791667
# 4                     Idilio (Felchlin)  3.775000

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='manufacturer', y='rating', data=top5_bar_makers, markers=True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Manufacturers with the top ratings.
# Ocelot, Heirloom Cacao Preservation (Zokoko), Matale, Patric, Idilio (Felchlin) are the topmost rated chocolate bar makers. Now going forward, we'll combine the top 5 bean origin countries with the top 5 manufacturers to see the ratings

# %%
last5_country_rating = country_avg_rating.tail()
last5_country_rating
# Out:
#               bean_origin    rating
# 57             Martinique  2.750000
# 58           Sierra Leone  2.750000
# 59               Principe  2.750000
# 60  St.Vincent-Grenadines  2.750000
# 61            Puerto Rico  2.714286

# %% [markdown]
# Averagely, Chocolates made of cocoa beans from Puerto Rico are the worst rated chocolates and it's adviced that manufacturers avoid these cocoa beans.

# %%
# Now, for each of these countries let's find the total number of chocolates reviewed.
review_count = df.groupby('bean_origin')[['review']].count().reset_index()
review_count
# Out:
#    bean_origin  review
# 0    Australia       3
# 1       Belize      74
# 2        Blend     144
# 3      Bolivia      79
# 4       Brazil      77
# ..         ...     ...
# 57      U.S.A.      31
# 58      Uganda      18
# 59     Vanuatu      12
# 60   Venezuela     246
# 61     Vietnam      73
#
# [62 rows x 2 columns]

# %%
review_count_top5 = review_count[['bean_origin','review']].sort_values('review', ascending=False).head()
review_count_top5
# Out:
#            bean_origin  review
# 60           Venezuela     246
# 36                Peru     231
# 13  Dominican Republic     220
# 14             Ecuador     201
# 28          Madagascar     171

# %%
sns.barplot(x='bean_origin', y='review', data=review_count_top5)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(9,12))
sns.barplot(x="review", y="bean_origin", data=review_count, units='review')
plt.xlabel('No of chocolates')
plt.show()

# %%
# compare cocoa content and rating using heatmap.
# first get the cocoa_percentage and rating from the dataset and get the correlation between them.
cocoa_and_rating = df[['cocoa_percent','rating']]
cocoa_and_rating.corr()
# Out:
#                cocoa_percent    rating
# cocoa_percent       1.000000 -0.077173
# rating             -0.077173  1.000000

# %%
sns.heatmap(cocoa_and_rating.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There exist a weak negative (no significant linear relationship) correlation between cocoa content and rating such that, an increase in cocoa percentage will lead to a slight decrease in the rating of a chocolate bar.

# %% [markdown]
# To investigate further, let's try to check for outliers in the two columns(i.e. cocoa_percent and rating)

# %%
rating_outliers = sns.boxplot(data=cocoa_and_rating['rating'])

# %%
cocoa_percent_outliers = sns.boxplot(data=cocoa_and_rating['cocoa_percent'])

# %% [markdown]
# There seems to be outliers in the cocoa_percent column and rating column .

# %%
# Check for the average cocoa content in chocolate bars whose rating are  above 3.5.
higher_rating_bars = df.loc[df['rating']>3.5]
higher_rating_bars
# Out:
#         id       manufacturer company_location  year_reviewed  \
# 2     2454               5150           U.S.A.           2019
# 8      797           A. Morin           France           2012
# 17    1011           A. Morin           France           2013
# 18    1015           A. Morin           France           2013
# 19    1019           A. Morin           France           2013
# ...    ...                ...              ...            ...
# 2508  2048  Zoto (Chocolatoa)          Belgium           2018
# 2513   647             Zotter          Austria           2011
# 2523   875             Zotter          Austria           2012
# 2524   879             Zotter          Austria           2012
# 2526  1996             Zotter          Austria           2017
#
#              bean_origin                              bar_name  cocoa_percent  \
# 2             Madagascar                Bejofo Estate, batch 1           76.0
# 8                   Peru                                  Peru           63.0
# 17               Ecuador                              Equateur           70.0
# 18             Venezuela                                 Chuao           70.0
# 19                  Peru                  Chanchamayo Province           63.0
# ...                  ...                                   ...            ...
# 2508           Nicaragua  El Castillero, batch ca1705, 3 turns           70.0
# 2513                Peru                                  Peru           70.0
# 2523  Dominican Republic    Loma Los Pinos, Yacao region, D.R.           62.0
# 2524  Dominican Republic                         Santo Domingo           70.0
# 2526            Colombia                      APROCAFA, Acandi           75.0
#
#       num_ingredients ingredients                           review  rating
# 2                 3.0       B,S,C     cocoa, blackberry, full body    3.75
# 8                 4.0     B,S,C,L            fruity, melon, roasty    3.75
# 17                4.0     B,S,C,L         sandy, nutty, cocoa, fig    3.75
# 18                4.0     B,S,C,L    oily, nut, caramel, raspberry    4.00
# 19                3.0       B,S,C          sweet, cocoa, tangerine    4.00
# ...               ...         ...                              ...     ...
# 2508              3.0       B,S,C  large grits, sweet, dried fruit    3.75
# 2513              4.0   B,S*,C,Sa        creamy, fatty, mild nutty    3.75
# 2523              4.0   B,S*,C,Sa    spice, caramel, toffee, salty    3.75
# 2524              4.0   B,S*,C,Sa          strawberry, Cadbury egg    3.75
# 2526              3.0       B,S,C        strong nutty, marshmallow    3.75
#
# [406 rows x 11 columns]

# %% [markdown]
# There are 406 chocolate bars with rating above 3.5

# %%
higher_rating_bars.nlargest(5, columns=['rating','cocoa_percent'])
# Out:
#         id      manufacturer company_location  year_reviewed bean_origin  \
# 2165  1077              Soma           Canada           2013       Blend
# 2051   959  Scharffen Berger           U.S.A.           2012        Peru
# 298     48            Bonnat           France           2006   Venezuela
# 299     81            Bonnat           France           2006   Venezuela
# 301    199            Bonnat           France           2008   Venezuela
#
#                                     bar_name  cocoa_percent  num_ingredients  \
# 2165  Crazy 88, Guat., D.R., Peru, Mad., PNG           88.0              3.0
# 2051                       San Juan de Cheni           78.0              4.0
# 298                    Maracaibo, El Rosario           75.0              3.0
# 299                                    Chuao           75.0              3.0
# 301                     Porcelana, Venezuela           75.0              3.0
#
#      ingredients                       review  rating
# 2165       B,S,C  pronounced berry,mild smoke     4.0
# 2051     B,S,C,L  banana, pear, spice, cheese     4.0
# 298        B,S,C        creamy, fatty, floral     4.0
# 299        B,S,C        creamy, coconut, tang     4.0
# 301        B,S,C    creamy, strawberry, nutty     4.0

# %%
id_rating = higher_rating_bars.groupby('rating')[['id']].count().reset_index()
id_rating
# Out:
#    rating   id
# 0    3.75  295
# 1    4.00  111

# %% [markdown]
# Also, chocolate bars with rating above 3.5 are either rated 3.75 or 4.00

# %%
# Average cocoa content for chocolate bars with rating above 3.5
avg_cocoa_content = higher_rating_bars['cocoa_percent'].mean()
avg_cocoa_content
# Out:
# 70.99630541871922

# %% [markdown]
# The average cocoa content in chocolate bars with rating above 3.5 is 70.996% (71%, approximately)

# %%
least_rated_bars = df.loc[df['rating']<3.5]
least_rated_bars.head()
# Out:
#      id manufacturer company_location  year_reviewed bean_origin  \
# 0  2454         5150           U.S.A.           2019    Tanzania
# 3  2542         5150           U.S.A.           2021        Fiji
# 4  2546         5150           U.S.A.           2021   Venezuela
# 5  2546         5150           U.S.A.           2021      Uganda
# 9  1011     A. Morin           France           2013      Panama
#
#                    bar_name  cocoa_percent  num_ingredients ingredients  \
# 0     Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 3     Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4     Sur del Lago, batch 1           72.0              3.0       B,S,C
# 5  Semuliki Forest, batch 1           80.0              3.0       B,S,C
# 9                    Panama           70.0              4.0     B,S,C,L
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# 3                chewy, off, rubbery    3.00
# 4  fatty, earthy, moss, nutty,chalky    3.00
# 5  mildly bitter, basic cocoa, fatty    3.25
# 9    brief fruit note, earthy, nutty    2.75

# %%
# Average cocoa content for chocolate bars with rating below 3.5
avg_cocoa_content_l = least_rated_bars['cocoa_percent'].mean()
avg_cocoa_content_l
# Out:
# 71.73299663299663

# %% [markdown]
# The average cocoa content in chocolate bars with higher ratings is less than that of chocolate bars with somewhat lower ratings. Could this mean that customers like chocolate bars which has less amount of cocoa in them? Personally I don't think so, because comparing the the averages, they are very close to each other and therefore i think it can't be concluded that customers like chocolate with less cocoa content more than chocolate with more cocoa content. And this is actually true in real world scenarios, people love chocolate bars with more cocoa content.

# %%
# number of different combinations of ingredients
df.ingredients.nunique()
# Out:
# 21

# %%
# Get the chocolate bars with lecithin from the dataset
lecithin_bars = df.loc[df['ingredients'].str.contains('L', regex=True)]
lecithin_bars
# Out:
#         id manufacturer company_location  year_reviewed       bean_origin  \
# 7      797     A. Morin           France           2012           Bolivia
# 8      797     A. Morin           France           2012              Peru
# 9     1011     A. Morin           France           2013            Panama
# 10    1015     A. Morin           France           2013          Colombia
# 11    1011     A. Morin           France           2013        Madagascar
# ...    ...          ...              ...            ...               ...
# 2500   697       Zokoko        Australia           2011           Bolivia
# 2501   701       Zokoko        Australia           2011  Papua New Guinea
# 2502   701       Zokoko        Australia           2011           Bolivia
# 2503  1780       Zokoko        Australia           2016             Blend
# 2504  1716       Zokoko        Australia           2016   Solomon Islands
#
#                   bar_name  cocoa_percent  num_ingredients ingredients  \
# 7                  Bolivia           70.0              4.0     B,S,C,L
# 8                     Peru           63.0              4.0     B,S,C,L
# 9                   Panama           70.0              4.0     B,S,C,L
# 10                Colombie           70.0              4.0     B,S,C,L
# 11     Madagascar, Criollo           70.0              4.0     B,S,C,L
# ...                    ...            ...              ...         ...
# 2500             Alto Beni           68.0              4.0     B,S,C,L
# 2501               Tokiala           66.0              4.0     B,S,C,L
# 2502  Tranquilidad, Baures           72.0              4.0     B,S,C,L
# 2503         Goddess Blend           65.0              5.0   B,S,C,V,L
# 2504           Guadalcanal           78.0              4.0     B,S,C,L
#
#                                review  rating
# 7                      vegetal, nutty    3.50
# 8               fruity, melon, roasty    3.75
# 9     brief fruit note, earthy, nutty    2.75
# 10       burnt rubber,alkalyzed notes    2.75
# 11            sticky, red fruit, sour    3.00
# ...                               ...     ...
# 2500           oily, honey, light rum    3.50
# 2501    toffee, caramel, butterscotch    3.50
# 2502          intense prune and berry    3.75
# 2503        oily, sweet, choco, nutty    3.25
# 2504    smokey, dried fruit, balanced    3.75
#
# [493 rows x 11 columns]

# %%
# Average rating of chocolate bars with Lecithin ingredient in thier content.
lecithin_bars['rating'].mean()
# Out:
# 3.150608519269777

# %%
# get chocolate bar
no_lecithin_bars = df.loc[df['ingredients'].str.contains('L')==False]
no_lecithin_bars
# Out:
#         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454         5150           U.S.A.           2019            Tanzania
# 1     2458         5150           U.S.A.           2019  Dominican Republic
# 2     2454         5150           U.S.A.           2019          Madagascar
# 3     2542         5150           U.S.A.           2021                Fiji
# 4     2546         5150           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2525  1205       Zotter          Austria           2014               Blend
# 2526  1996       Zotter          Austria           2017            Colombia
# 2527  2036       Zotter          Austria           2018               Blend
# 2528  2170       Zotter          Austria           2018               Congo
# 2529  2170       Zotter          Austria           2018              Belize
#
#                              bar_name  cocoa_percent  num_ingredients  \
# 0               Kokoa Kamili, batch 1           76.0              3.0
# 1                     Zorzal, batch 1           76.0              3.0
# 2              Bejofo Estate, batch 1           76.0              3.0
# 3               Matasawalevu, batch 1           68.0              3.0
# 4               Sur del Lago, batch 1           72.0              3.0
# ...                               ...            ...              ...
# 2525                              Raw           80.0              4.0
# 2526                 APROCAFA, Acandi           75.0              3.0
# 2527  Dry Aged, 30 yr Anniversary bar           75.0              3.0
# 2528            Mountains of the Moon           70.0              3.0
# 2529                         Maya Mtn           72.0              3.0
#
#      ingredients                             review  rating
# 0          B,S,C          rich cocoa, fatty, bready    3.25
# 1          B,S,C             cocoa, vegetal, savory    3.50
# 2          B,S,C       cocoa, blackberry, full body    3.75
# 3          B,S,C                chewy, off, rubbery    3.00
# 4          B,S,C  fatty, earthy, moss, nutty,chalky    3.00
# ...          ...                                ...     ...
# 2525   B,S*,C,Sa             waxy, cloying, vegetal    2.75
# 2526       B,S,C          strong nutty, marshmallow    3.75
# 2527       B,S,C               fatty, earthy, cocoa    3.00
# 2528       B,S,C       fatty, mild nuts, mild fruit    3.25
# 2529       B,S,C          muted, roasty, accessible    3.50
#
# [1950 rows x 11 columns]

# %%
# comfirming that this subset of the dataset actually doesn't contain Lecithin

no_lecithin_bars['ingredients'].str.contains('L').sum()
# Out:
# 0

# %%
# Average rating of bars without lecithin ingredient

no_lecithin_bars.rating.mean()
# Out:
# 3.2251282051282053

# %% [markdown]
# Bars without the Lecithin ingredient is rated higher than those with the Lecithin ingredients in their content. Because the average rating of bars without Lecithin is 3.225 as compared to 3.15 of chocolate bars with Lecithin.

# %%
# Let's do a little time series analysis of chocolate production

yearly_reviews = df.groupby('year_reviewed')[['id']].count().reset_index()
yearly_reviews
# Out:
#     year_reviewed   id
# 0            2006   60
# 1            2007   69
# 2            2008   84
# 3            2009  113
# 4            2010   94
# 5            2011  153
# 6            2012  180
# 7            2013  177
# 8            2014  243
# 9            2015  280
# 10           2016  213
# 11           2017  103
# 12           2018  225
# 13           2019  193
# 14           2020   81
# 15           2021  175

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(data=df, x='year_reviewed')
ax.set_ylabel('number of reviews')
ax.set_xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %% [markdown]
# # Summary
#
# - There exists a weak negative correlation between cocoa content and rating. i.e., there is no meaningful linear
#     relationship between cocoa content and rating. Meaning, consumers do not rate a chocolate bar based on the cocoa
#     content in it.
# - The average cocoa content in bars with higher rating (rating > 3.5) is 70.996%, which is closer to 71.7% of
#     chocolate bars with rating less than 3.5
# - The rating of chocolate bars differ by cocoa bean's origin. Therefore, cocoa bean's origin is an indicator of
#   quality
# - The average rating of chocolate bars without lecithin ingredient is 3.22 and that of bars with lecithin
#     ingredients is 3.15 . This implies that, bar without lecithin is much appreciated or loved by consumers as
#     compared to bars with the lecithin ingredients.
# - Finally, in finding the best chocolate bars, the following should be checked;
#     1. the cocoa bean should have originated from one(1) of the following countries China, Sao Tome & Principe,
#         Solomon Island, Congo and Thailand. Reason being that, chocolate bars from these countries are mostly rated
#         higher.
#     2. the makers/producers of a particular chocolate bar should be one of Ocelot, Heirloom Cacao Preservation
#         (Zokoko), Matale,Patric, Idilio (Felchlin).
